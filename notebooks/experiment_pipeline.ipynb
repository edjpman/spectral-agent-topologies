# %% [markdown]
# # Analysis of the Experiment

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.append(str(ROOT))

from src.eval.exp_analysis import main

#The official experimental dataset
# -- qwen25_full_spectral_run_t08_p05_e15_tr35_v2.json
# -- qwen25_full_spectral_run_t08_p05_e15_tr100.json
results_path = ROOT / "data" / "qwen25_full_spectral_run_t08_p05_e15_tr100.json"

# %% [markdown]
# ### Experimental Results

# %%
results = main(results_path)
# Out:
# Loading: /Users/ethanparks/Desktop/repos/spectral-agent-topologies/data/qwen25_full_spectral_run_t08_p05_e15_tr100.json
#
# ----------------------------------------------------------------------------------------------------------------------------------
# Topology   | Convergence                | Stability                  | Robustness                 | Failure Rate
# ----------------------------------------------------------------------------------------------------------------------------------
# Chain      | 0.000 | 0.27±0.08 | 27.0% | 1.000 | 2094.34±843.05 | 3.0% | 9.945 | 237.82±190.51 | 36.1% | 0.0%
# Mesh       | 9.231 | -1.66±2.25 | 27.0% | 10.000 | 1241.00±950.01 | 3.0% | 13.000 | 247.42±198.51 | 36.1% | 0.0%
# Star       | 9.000 | -3.44±2.40 | 27.0% | 10.000 | 1184.24±951.91 | 3.0% | 28.610 | 443.64±307.45 | 36.1% | 3.0%
# ----------------------------------------------------------------------------------------------------------------------------------
# ...
